# %%
import pandas as pd
from bs4 import BeautifulSoup
arr=[]
records = []
for year in range(1958,2023):
    regu="https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                print('yes')
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#WIFU-reg")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)

    
    
for year in range(1907,1956):
    regu="https://stats.cfldb.ca/league/irfu/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                print('yes')
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    regu=("https://stats.cfldb.ca/league/irfu/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/irfu/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)

    
for year in range(1956,1958):
    regu="https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                print('yes')
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#WIFU-reg")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)
    
    
for year in range(1883,1961):
    regu="https://stats.cfldb.ca/league/orfu/schedule/"+str(year)+"/#reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                print('yes')
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    
    print(year)
# Out:
# yes
# yes
# 1958
# yes
# 1959
# yes
# yes
# 1960
# yes
# yes
# yes
# 1961
# yes
# 1962
# 1963
# yes
# 1964
# yes
# yes
# 1965
# yes
# yes
# 1966
# yes
# yes
# 1967
# yes
# 1968
# yes
# 1969
# yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27/772244566.py in <module>
#     100     reghh=regh.encode("ascii",errors='replace')
#     101     reghz=reghh.decode("ascii",errors='replace')
# --> 102     regz=BeautifulSoup(reghz)
#     103     regt=regz.find_all("table")
#     104
#
# /opt/conda/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331             self.builder.initialize_soup(self)
#     332             try:
# --> 333                 self._feed()
#     334                 success = True
#     335                 break
#
# ...

# %%
'vs' in str(rowz)
# Out:
# True

# %%
df=pd.concat([pd.DataFrame(records)])
df[df.neutral==True]
# Out:
#       neutral                  Date               Result Attendance        TV  \
# 36       True   Sun Sep 14\n2:00 PM     OTT 18 vs HAM 24     15,110      CBCE
# 103      True   Sat Nov 29\n4:00 PM     WPG 35 vs HAM 28     36,567  CBC, R/C
# 140      True   Sun Sep 14\n2:00 PM     OTT 18 vs HAM 24     15,110      CBCE
# 207      True   Sat Nov 29\n4:00 PM     WPG 35 vs HAM 28     36,567  CBC, R/C
# 244      True   Sun Sep 14\n2:00 PM     OTT 18 vs HAM 24     15,110      CBCE
# 311      True   Sat Nov 29\n4:00 PM     WPG 35 vs HAM 28     36,567  CBC, R/C
# 348      True   Sun Sep 14\n2:00 PM     OTT 18 vs HAM 24     15,110      CBCE
# 415      True   Sat Nov 29\n4:00 PM     WPG 35 vs HAM 28     36,567  CBC, R/C
# 514      True   Sat Nov 28\n1:00 PM      WPG 21 vs HAM 7     33,133       CBC
# 613      True   Sat Nov 28\n1:00 PM      WPG 21 vs HAM 7     33,133       CBC
# 712      True   Sat Nov 28\n1:00 PM      WPG 21 vs HAM 7     33,133       CBC
# ...

# %%
df=pd.concat([pd.DataFrame(records)])
df.sort_values(by='Date')
df.at[914,'isneutral']=True
df.at[1315,'isneutral']=True
df.at[1681,'isneutral']=True
df.at[2402,'isneutral']=True
df.at[2768,'isneutral']=True
df.at[3138,'isneutral']=True
df.at[3502,'isneutral']=True
df.at[3868,'isneutral']=True
df.at[4240,'isneutral']=True
df.at[4614,'isneutral']=True
df.at[4993,'isneutral']=True
df.at[5739,'isneutral']=True
df.at[6111,'isneutral']=True
df.at[6494,'isneutral']=True
df.at[6875,'isneutral']=True
df.at[7643,'isneutral']=True
df.at[8406,'isneutral']=True
df.at[8786,'isneutral']=True
df.at[9930,'isneutral']=True
df.at[10310,'isneutral']=True
df.at[10692,'isneutral']=True
df.at[11069,'isneutral']=True
df.at[11413,'isneutral']=True
df.at[11757,'isneutral']=True
df.at[12445,'isneutral']=True
df.at[12789,'isneutral']=True
df.at[13143,'isneutral']=True
df.at[14076,'isneutral']=True
df.at[14582,'isneutral']=True
df.at[14952,'isneutral']=True
df.at[15292,'isneutral']=True
df.at[15632,'isneutral']=True
df.at[15972,'isneutral']=True
df.at[16312,'isneutral']=True
df.at[17042,'isneutral']=True
df.at[17422,'isneutral']=True
df.at[17802,'isneutral']=True
df.at[18712,'isneutral']=True
df.at[18512,'isneutral']=True
df.at[18852,'isneutral']=True
df.at[19192,'isneutral']=True
df.at[19532,'isneutral']=True
df.at[20902,'isneutral']=True
df.at[21282,'isneutral']=True
df.at[21662,'isneutral']=True
df.at[22042,'isneutral']=True
df.at[22422,'isneutral']=True
df.at[22802,'isneutral']=True
df.at[23834,'isneutral']=True
df[df.fd==20221120]

# %%
df.to_csv("cflgames.csv")

# %%
for key in ct:
    print(key,":",eloLeague.ratingDict[key])

# %%
fn=str(row.season)+key+".txt"
            import os
            if(os.path.exists(fn))==True:
                contents = open(fn).read()
                if 'nan' not in contents:
                    contents=float(contents)
                    if(row.season==2021):
                        vegw=(14-contents)*-20
                        vegw=round(vegw)
                    if(row.season==2022):
                        vegw=(18-contents)*-20
                        vegw=round(vegw)
                    eloLeague.ratingDict[key]+=vegw

# %%
df=pd.DataFrame(records)
df= df.drop_duplicates()
df=df[df.season!=2020]
df=df[df['Result'].notna()]
df['isneutral']=False
df.at[514,'isneutral']=True
df.at[914,'isneutral']=True
df.at[1315,'isneutral']=True
df.at[1681,'isneutral']=True
df.at[2402,'isneutral']=True
df.at[2768,'isneutral']=True
df.at[3138,'isneutral']=True
df.at[3502,'isneutral']=True
df.at[3868,'isneutral']=True
df.at[4240,'isneutral']=True
df.at[4614,'isneutral']=True
df.at[4993,'isneutral']=True
df.at[5739,'isneutral']=True
df.at[6111,'isneutral']=True
df.at[6494,'isneutral']=True
df.at[6875,'isneutral']=True
df.at[7643,'isneutral']=True
df.at[8406,'isneutral']=True
df.at[8786,'isneutral']=True
df.at[9930,'isneutral']=True
df.at[10310,'isneutral']=True
df.at[10692,'isneutral']=True
df.at[11069,'isneutral']=True
df.at[11413,'isneutral']=True
df.at[11757,'isneutral']=True
df.at[12445,'isneutral']=True
df.at[12789,'isneutral']=True
df.at[13143,'isneutral']=True
df.at[14076,'isneutral']=True
df.at[14582,'isneutral']=True
df.at[14952,'isneutral']=True
df.at[15292,'isneutral']=True
df.at[15632,'isneutral']=True
df.at[15972,'isneutral']=True
df.at[16312,'isneutral']=True
df.at[17042,'isneutral']=True
df.at[17422,'isneutral']=True
df.at[17802,'isneutral']=True
df.at[18712,'isneutral']=True
df.at[18512,'isneutral']=True
df.at[18852,'isneutral']=True
df.at[19192,'isneutral']=True
df.at[19532,'isneutral']=True
df.at[20902,'isneutral']=True
df.at[21282,'isneutral']=True
df.at[21662,'isneutral']=True
df.at[22042,'isneutral']=True
df.at[22422,'isneutral']=True
df.at[22802,'isneutral']=True
df.at[23834,'isneutral']=True
df.at[3137,'isneutral']=True
df.at[23770,'isneutral']=True
df.at[22759,'isneutral']=True
df.at[21199,'isneutral']=True
df.at[21263,'isneutral']=True
df.at[21266,'isneutral']=True
df.at[19503,'isneutral']=True
df=df[df.index!=18712]
df.at[19843,'isneutral']=True
df.at[20483,'isneutral']=True
df.at[20486,'isneutral']=True
df.at[20494,'isneutral']=True
df.at[20506,'isneutral']=True
df.at[20513,'isneutral']=True
df.at[20521,'isneutral']=True
df.at[20525,'isneutral']=True
df.at[20542,'isneutral']=True
df.at[20548,'isneutral']=True
df.at[36,'isneutral']=True
df.sort_values(by='Date')
df.at[6875,'isneutral']=True
df.at[7643,'isneutral']=True
df.at[8406,'isneutral']=True
df.at[8786,'isneutral']=True
df.at[9930,'isneutral']=True
df.at[10310,'isneutral']=True
df.at[10692,'isneutral']=True
df.at[11069,'isneutral']=True
df.at[11413,'isneutral']=True
df.at[11757,'isneutral']=True
df.at[12445,'isneutral']=True
df.at[12789,'isneutral']=True
df.at[13143,'isneutral']=True
df.at[14076,'isneutral']=True
df.at[14582,'isneutral']=True
df.at[14952,'isneutral']=True
df.at[15292,'isneutral']=True
df.at[15632,'isneutral']=True
df.at[914,'isneutral']=True
df.at[1315,'isneutral']=True
df.at[1681,'isneutral']=True
df.at[2402,'isneutral']=True
df.at[2768,'isneutral']=True
df.at[3138,'isneutral']=True
df.at[3502,'isneutral']=True
df.at[3868,'isneutral']=True
df.at[4240,'isneutral']=True
df.at[4614,'isneutral']=True
df.at[4993,'isneutral']=True
df.at[5739,'isneutral']=True
df.at[6111,'isneutral']=True
df.at[6494,'isneutral']=True
df.at[6875,'isneutral']=True
df.at[7643,'isneutral']=True
df.at[8406,'isneutral']=True
df.at[8786,'isneutral']=True
df.at[9930,'isneutral']=True
df.at[10310,'isneutral']=True
df.at[10692,'isneutral']=True
df.at[11069,'isneutral']=True
df.at[11413,'isneutral']=True
df.at[11757,'isneutral']=True
df.at[12445,'isneutral']=True
done=0
z=[]
g=1
for row in df.itertuples():
    res = []
    test_string=row.Result
    x=test_string.split()
    
    date=row.Date.split()
    datez=[]
    for i in date:
        
        if i.isnumeric()!=True:
            datez.append(str(i))
    
    if(done!=1):
        print(date)
        done=1
    dnum=date[2]
    date=datez
    
    if(date[1])=='Jan':
        month=1
    if(date[1])=='Feb':
        month=2
    if(date[1])=='Mar':
        month=3
    if(date[1])=='Apr':
        month=4
    if(date[1])=='May':
        month=5
    if(date[1])=='Jun':
        month=6
    if(date[1])=='Jul':
        month=7
    if(date[1])=='Aug':
        month=8
    if(date[1])=='Sep':
        month=9
    if(date[1])=='Oct':
        month=10
    if(date[1])=='Nov':
        month=11
    if(date[1])=='Dec':
        month=12
    fd=str(row.season)+str(month)+str(dnum)
    fd=fd.replace("Jan","1")
    fd=fd.replace("Feb","2")
    fd=fd.replace("Mar","3")
    fd=fd.replace("Apr","4")
    fd=fd.replace("May","5")
    fd=fd.replace("Jun","6")
    fd=fd.replace("Jul","7")
    fd=fd.replace("Aug","8")
    fd=fd.replace("Sep","9")
    fd=fd.replace("Oct","10")
    fd=fd.replace("Nov","11")
    fd=fd.replace("Dec","12")
    fd=fd.replace("'","")
    fd=float(fd)
    if g==1:
        print(date[1])
        g=0
    t1s=x[4]
    t2s=x[1]
    t1=x[3]
    t2=x[0]
    if(len(date)==4):
        time=str(date[2])+str(date[3])
    if(len(date)==5):
        time=str(date[3])+str(date[4])
    if "vs" in row.Result:
        t1s=x[1]
        t2s=x[4]
        t1=x[0]
        t2=x[3]
    df.at[row.Index,'neutral']=x[2]
    df.at[row.Index,'score2']=t2s
    df.at[row.Index,'score1']=t1s
    df.at[row.Index,'team2']=t2
    df.at[row.Index,'team1']=t1
    df.at[row.Index,'time']=time
    df.at[row.Index,'fd']=fd
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()

# %%
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()

# %%
import math
import numpy as np
df.at[103,'isneutral']=True
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()
class Elo:
    
    
    def __init__(self,k,g=1,homefield = 100):
        self.ratingDict = {}
        self.k = k
        self.homefield= homefield

    def addPlayer(self,name,rating = 1500):
        self.ratingDict[name] = rating
    def gameOver(self, winner, loser, ws,ls,neutral,winnerHome):
        hfa=60
        if neutral==True:
            hfa=0
        if winnerHome:
            result = self.expectResult(self.ratingDict[winner] + hfa, self.ratingDict[loser])
        else:
            result = self.expectResult(self.ratingDict[winner], self.ratingDict[loser]+hfa)
        pd=abs(ws-ls)
        tie=0
        if(ws==ls):
            tie=1
       
        if winnerHome==True:
            elo_diff=((eloLeague.ratingDict[winner]+hfa)-eloLeague.ratingDict[loser])
        if winnerHome==False:
            elo_diff=((eloLeague.ratingDict[winner])-(eloLeague.ratingDict[loser]+hfa))
        mult=math.log(max(pd,1)+1)*(2.2 / (1.0 if  tie == 1 else ((elo_diff if tie == 1 else -elo_diff) * 0.001 + 2.2)))
        shift=(self.k*mult)*(1 - result)  
        self.ratingDict[winner]+=shift
        self.ratingDict[loser]-=shift
    def expectResult(self, p1, p2):
        exp = (p2-p1)/400.0
        return 1/((10.0**(exp))+1)
df.sort_values(by='fd')
df["score1"] = pd.to_numeric(df["score1"])
df["score2"] = pd.to_numeric(df["score2"])
df["sseason"] = pd.to_numeric(df["season"])
eloLeague=Elo(k=20,homefield=60)
teams=set(df.team1.tolist()+df.team2.tolist())
for team in teams:
    eloLeague.addPlayer(team,rating=1500)
cs=1958
w=0
l=0
for row in df.itertuples():
    currs=row.season
teny=currs-10
hfaz=[]

      
for row in df.itertuples():
    if(row.season>cs):
        csdf=df[df.season==row.season]
        ct=set(csdf.team1.tolist()+csdf.team2.tolist())
        lsdf=df[df.season<row.season]
        lt=set(lsdf.team1.tolist()+lsdf.team2.tolist())
        for key in eloLeague.ratingDict.keys():
            fn=str(row.season)+key+".txt"
            import os
            if(os.path.exists(fn))==True:
                contents = open(fn).read()
                if 'nan' not in contents:
                    contents=float(contents)
                    if(row.season==2021):
                        vegw=(7-contents)*-20
                        vegw=round(vegw)
                    if(row.season==2022):
                        vegw=(9-contents)*-20
                        vegw=round(vegw)
                    
                    vegw=vegw*(0.61)
                    eloLeague.ratingDict[key]+=vegw
            if(key in lt and key in ct):
                eloLeague.ratingDict[key]=((0.61)*eloLeague.ratingDict[key])+(1500*(0.39))
        cs=row.season
    hfa=60
    if(row.score1>row.score2):
        wh=True
        
        if(row.isneutral==True):
            hfa=0
        if((eloLeague.ratingDict[row.team1]+hfa)>eloLeague.ratingDict[row.team2]):
            w+=1
        if((eloLeague.ratingDict[row.team1]+hfa)<eloLeague.ratingDict[row.team2]):
            l+=1
        eloLeague.gameOver(row.team1,row.team2,row.score1,row.score2,row.isneutral,wh)
    if(row.score1<row.score2):
        
        wh=False
        
        if(row.isneutral==True):
            hfa=0
        if((eloLeague.ratingDict[row.team1]+hfa)>eloLeague.ratingDict[row.team2]):
            l+=1
        if((eloLeague.ratingDict[row.team1]+hfa)<eloLeague.ratingDict[row.team2]):
            w+=1
        eloLeague.gameOver(row.team2,row.team1,row.score2,row.score1,row.isneutral,wh)
    if(row.score1==row.score2):
        wh=True
        eloLeague.gameOver(row.team1,row.team2,row.score1,row.score2,row.isneutral,wh)

# %%
df[df.fd==19581129]
df.at[103,'isneutral']=True

# %% [markdown]
# # Without veg
# accuracy with mean rev of 1/3:64.39393939393939
# accuracy with mean rev of 0.34:64.42837465564739
# accuracy with mean rev of 0.35:64.48002754820936
# accuracy with mean rev of 0.36:64.48002754820936
# acurracy with mean rev of 0.37:64.53168044077135
# accuracy with mean rev of 0.38:64.53168044077135
# accuracy with mean rev of 0.39:64.58333333333333
# accuracy with mean rev of 0.40:64.54889807162535

# %%
df.at[888,'Attendance']=0
for row in df.itertuples():
    a=str(row.Attendance)
    az=a.replace(",","")
    if len(az)==0:
        a=0
    if len(az)>0:
        a=float(az)
    df.at[row.Index,'Attendance']=a
df["Attendance"] = pd.to_numeric(df["Attendance"])
na=df[df.Attendance<1000]

# %%
print(100/(w+l)*w)

# %%
n=df[df.isneutral==True]
n

# %%
df.at[3137,'isneutral']=True
df.at[23770,'isneutral']=True
df.at[22759,'isneutral']=True
df.at[21199,'isneutral']=True
df.at[21263,'isneutral']=True
df.at[21266,'isneutral']=True
df.at[19503,'isneutral']=True
df.at[19843,'isneutral']=True
df.at[20483,'isneutral']=True
df.at[20486,'isneutral']=True
df.at[20494,'isneutral']=True
df.at[20506,'isneutral']=True
df.at[20513,'isneutral']=True
df.at[20521,'isneutral']=True
df.at[20525,'isneutral']=True
df.at[20542,'isneutral']=True
df.at[20548,'isneutral']=True
