# %%
import pandas as pd
from bs4 import BeautifulSoup
arr=[]
records = []
for year in range(1958,2023):
    regu="https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#WIFU-reg")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/cfl/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)
# Out:
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
df.to_csv("cfl1958-2022.csv")

# %%
df=pd.concat([pd.DataFrame(records)])
df.to_csv("cfl.csv")

# %%
df.to_csv("cflgamess.csv")

# %%
for key in ct:
    print(key,":",eloLeague.ratingDict[key])

# %%
fn=str(row.season)+key+".txt"
            import os
            if(os.path.exists(fn))==True:
                contents = open(fn).read()
                if 'nan' not in contents:
                    contents=float(contents)
                    if(row.season==2021):
                        vegw=(14-contents)*-20
                        vegw=round(vegw)
                    if(row.season==2022):
                        vegw=(18-contents)*-20
                        vegw=round(vegw)
                    eloLeague.ratingDict[key]+=vegw

# %%
y=str('5t')
y.isdigit()
# Out:
# False

# %%
df=pd.DataFrame(records)
df.sort_values(by='Date',inplace=True)
df.season.unique()
df[df.index==1]
# Out:
#    neutral                 Date           Result Attendance TV  season
# 1    False  Thu Jul 31\n8:00 PM  WPG 15 @ TOR 22     12,584       1958

# %%
'15' in str(row.Result)
# Out:
# False

# %%
str(row.Result)
# Out:
# 'McG  @ TOR'

# %%
row.Index
# Out:
# 24381

# %%
df=pd.DataFrame(records)
df.at[24366,'Result']="McG 0 @ TOR 2"
df=df[df.index!=25592]
df['Notes']='none'
df.at[24366,'Notes']="McG forfited"
df= df.drop_duplicates()
df=df[df.season!=2020]
done=0
z=[]
g=1
yrs=[]
ty=0
tf=0
df=df[df.Result!='QUE 0 @ TOR']
for row in df.itertuples():
    h=str(row.Result)
    if float(row.season) not in yrs:
        yrs.append(float(row.season))
        print(row.season)
    h=str(row.Result)
    
    if any(chr.isdigit() for chr in h)==False:
        tf+=1
        df=df[df.index!=row.Index]
    else:
        ty+=1
print('done')
for row in df.itertuples():
    h=str(row.Result)
    if float(row.season) not in yrs:
        yrs.append(float(row.season))
        print(row.season)
    h=str(row.Result)
    
        
    res = []
    
    
    test_string=row.Result
    x=test_string.split()
    
    date=row.Date.split()
    datez=[]
    for i in date:
        
        if i.isnumeric()!=True:
            datez.append(str(i))
    
    if(done!=1):
        print(date)
        done=1
    dnum=date[2]
    date=datez
    
    if(date[1])=='Jan':
        month=1
    if(date[1])=='Feb':
        month=2
    if(date[1])=='Mar':
        month=3
    if(date[1])=='Apr':
        month=4
    if(date[1])=='May':
        month=5
    if(date[1])=='Jun':
        month=6
    if(date[1])=='Jul':
        month=7
    if(date[1])=='Aug':
        month=8
    if(date[1])=='Sep':
        month=9
    if(date[1])=='Oct':
        month=10
    if(date[1])=='Nov':
        month=11
    if(date[1])=='Dec':
        month=12
    fd=str(row.season)+str(month)+str(dnum)
    fd=fd.replace("Jan","1")
    fd=fd.replace("Feb","2")
    fd=fd.replace("Mar","3")
    fd=fd.replace("Apr","4")
    fd=fd.replace("May","5")
    fd=fd.replace("Jun","6")
    fd=fd.replace("Jul","7")
    fd=fd.replace("Aug","8")
    fd=fd.replace("Sep","9")
    fd=fd.replace("Oct","10")
    fd=fd.replace("Nov","11")
    fd=fd.replace("Dec","12")
    fd=fd.replace("'","")
    fd=float(fd)
    if g==1:
        print(date[1])
        g=0
    t1s=x[4]
    t2s=x[1]
    t1=x[3]
    t2=x[0]
    if(len(date)==4):
        time=str(date[2])+str(date[3])
    if(len(date)==5):
        time=str(date[3])+str(date[4])
    if "vs" in row.Result:
        t1s=x[1]
        t2s=x[4]
        t1=x[0]
        t2=x[3]
    df.at[row.Index,'score2']=t2s
    df.at[row.Index,'score1']=t1s
    df.at[row.Index,'team2']=t2
    df.at[row.Index,'team1']=t1
    df.at[row.Index,'time']=time
    df.at[row.Index,'fd']=fd
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()
# Out:
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2021
# 2022
# done
# ['Tue', 'Jul', '29', '5:30', 'PM']
# Jul

# %%
df=df[df.index!=25592]
# Out:
# Pandas(Index=25592, neutral=False, Date='Sat Sep 25', Result='QUE 0 @ TOR', Attendance='', TV=nan, season=1937, Notes='none')

# %%
row
# Out:
# Pandas(Index=25615, neutral=False, Date='Sat Sep 25', Result='QUE 0 @ TOR', Attendance='', TV=nan, season=1937, Notes='none')

# %%
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()

# %%
df.to_csv("cflgamez.csv")

# %%
# Out:
# Empty DataFrame
# Columns: [neutral, Date, Result, Attendance, TV, season, Notes]
# Index: []

# %%
import math
import numpy as np
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()
u={}
u['yes']=0
class Elo:
    
    
    def __init__(self,k,g=1,homefield = 100):
        self.ratingDict = {}
        self.k = k
        self.homefield= homefield

    def addPlayer(self,name,rating = 1500):
        self.ratingDict[name] = rating
    def gameOver(self, winner, loser, ws,ls,neutral,winnerHome):
        hfa=60
        if 'True' in str(neutral):
            hfa=0
        if winnerHome:
            result = self.expectResult(self.ratingDict[winner] + hfa, self.ratingDict[loser])
        else:
            result = self.expectResult(self.ratingDict[winner], self.ratingDict[loser]+hfa)
        pd=abs(ws-ls)
        tie=0
        if(ws==ls):
            tie=1
       
        if winnerHome==True:
            elo_diff=((eloLeague.ratingDict[winner]+hfa)-eloLeague.ratingDict[loser])
        if winnerHome==False:
            elo_diff=((eloLeague.ratingDict[winner])-(eloLeague.ratingDict[loser]+hfa))
        mult=math.log(max(pd,1)+1)*(2.2 / (1.0 if  tie == 1 else ((elo_diff if tie == 1 else -elo_diff) * 0.001 + 2.2)))
        shift=(self.k*mult)*(1 - result)  
        if u['yes']==0:
            print((self.k*mult)*(1 - result)  )
            u['yes']=1
        self.ratingDict[winner]+=shift
        self.ratingDict[loser]-=shift
    def expectResult(self, p1, p2):
        exp = (p2-p1)/400.0
        return 1/((10.0**(exp))+1)
df.sort_values(by='fd')
df=df.rename(columns={'neutral':'isneutral'})
df=df.astype({"team1":"string","team2":"string","score2":float,'score1':float})
df["score1"] = pd.to_numeric(df["score1"])
df["score2"] = pd.to_numeric(df["score2"])
df["sseason"] = pd.to_numeric(df["season"])
eloLeague=Elo(k=20,homefield=60)
teams=set(df.team1.tolist()+df.team2.tolist())
for team in teams:
    eloLeague.addPlayer(team,rating=1500)
w=0
l=0
hfaz=[]

cs=1884

for row in df.itertuples():
    if(row.season>cs):
        csdf=df[df.season==row.season]
        ct=set(csdf.team1.tolist()+csdf.team2.tolist())
        lsdf=df[df.season<row.season]
        lt=set(lsdf.team1.tolist()+lsdf.team2.tolist())
        for key in eloLeague.ratingDict.keys():
           
            if(key in lt and key in ct):
                eloLeague.ratingDict[key]=((0.60)*eloLeague.ratingDict[key])+(1500*0.40)
        cs=float(row.season)
    hfa=60
    if(row.score1>row.score2):
        wh=True
        
        if(row.isneutral==True):
            hfa=0
        if((eloLeague.ratingDict[row.team1]+hfa)>eloLeague.ratingDict[row.team2]):
            w+=1
        if((eloLeague.ratingDict[row.team1]+hfa)<eloLeague.ratingDict[row.team2]):
            l+=1
        eloLeague.gameOver(row.team1,row.team2,row.score1,row.score2,row.isneutral,wh)
    if(row.score1<row.score2):
        
        wh=False
        
        if(row.isneutral==True):
            hfa=0
        if((eloLeague.ratingDict[row.team1]+hfa)>eloLeague.ratingDict[row.team2]):
            l+=1
        if((eloLeague.ratingDict[row.team1]+hfa)<eloLeague.ratingDict[row.team2]):
            w+=1
        eloLeague.gameOver(row.team2,row.team1,row.score2,row.score1,row.isneutral,wh)
    if(row.score1==row.score2):
        wh=True
        eloLeague.gameOver(row.team1,row.team2,row.score1,row.score2,row.isneutral,wh)
# Out:
# 30.05325619862182

# %%
((0.61)*eloLeague.ratingDict[key])+(1500*(0.39))
# Out:
# 1653.8570079662875

# %%
for key in eloLeague.ratingDict.keys():
    print(key,eloLeague.ratingDict[key])
# Out:
# WAS 1598.5031891885938
# CHIC 1609.2351099616396
# SHR 1324.8082841096314
# STL 1657.638940697754
# SAR 1379.1423290149876
# SAC 1507.0300417716567
# SA 1723.901928817333
# EAS 1401.4968108114062
# PIT 1655.7779913919283
# OTT 1265.4132941260682
# CFLAS 1637.1098454272023
# CGY 1715.1354200942596
# WIFUA 1577.1745617091053
# BRM 1495.0085433909765
# EDM 1202.546268564478
# KW 1376.9992247968344
# BC 1626.8429150404338
# SSK 1360.0647819134592
# IRFUA 1422.8254382908947
# BAL 1973.1210493102033
# TOR 1596.858610817254
# WPG 1782.7503166484023
# LDN 1374.5954539133518
# BUF 1412.687491316857
# HAM 1441.499400387193
# MTL 1506.2847929716145
# LV 1347.9039247241687
# CHI 1590.011778566994
# MPH 1492.868070616281

# %%
for year in range(1907,1956):
    regu="https://stats.cfldb.ca/league/irfu/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    regu=("https://stats.cfldb.ca/league/irfu/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/irfu/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)

    
for year in range(1956,1958):
    regu="https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#WIFU-reg")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)
    
    
for year in range(1883,1961):
    regu="https://stats.cfldb.ca/league/orfu/schedule/"+str(year)+"/#reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/cfc/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    
    print(year)

    
    
for year in range(1936,1957):
    regu="https://stats.cfldb.ca/league/wifu/schedule/"+str(year)+"/#reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/wifu/schedule/"+str(year)+"/#playoffs")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu=("https://stats.cfldb.ca/league/wifu/schedule/"+str(year)+"/#greycup")
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    
    print(year)
