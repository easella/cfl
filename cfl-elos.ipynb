# %%
import pandas as pd
from bs4 import BeautifulSoup
arr=[]
records = []
html=requests.get("https://stats.cfldb.ca/league/")
soup=BeautifulSoup(html.text)
con=soup.find("div",{"class":"card-body"})
links=[]

for a in con.find_all("a"):
    a=str(a)
    a=a.split("href=")
    a=a[1]
    a=a.split(">")[0]
    a=a.replace('"',"")
    a=a.replace("'","")
    a="https://stats.cfldb.com"+str(a)
    links.append(a)
startyear=input("start year")
startyear=int(startyear)
endyear=input("end year")
endyear=int(endyear)
league=input("league")
for year in range(startyear,endyear+1):
    
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#WIFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#playoffs"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)
# Out:
# start year 1956
# end year 1959
# league cfc
# 1956
# 1957
# 1958

# %% [markdown]
# records

# %%
df=pd.DataFrame(records)
df.to_csv("cfc.csv")

# %%
endyear+1
# Out:
# 1959

# %%
html=requests.get("https://stats.cfldb.ca/league/")
soup=BeautifulSoup(html.text)
con=soup.find("div",{"class":"card-body"})
links=[]

for a in con.find_all("a"):
    a=str(a)
    a=a.split("href=")
    a=a[1]
    a=a.split(">")[0]
    a=a.replace('"',"")
    a=a.replace("'","")
    a="https://stats.cfldb.com"+str(a)
    links.append(a)

# %%
links
# Out:
# ['https://stats.cfldb.com/league/cfc/',
#  'https://stats.cfldb.com/league/cfl/',
#  'https://stats.cfldb.com/league/erfu/',
#  'https://stats.cfldb.com/league/irfu/',
#  'https://stats.cfldb.com/league/tcrfu/',
#  'https://stats.cfldb.com/league/wcasrfl/',
#  'https://stats.cfldb.com/league/wifu/',
#  'https://stats.cfldb.com/league/arfu/',
#  'https://stats.cfldb.com/league/arfl/',
#  'https://stats.cfldb.com/league/bcru/',
#  'https://stats.cfldb.com/league/cgyrfu/',
#  'https://stats.cfldb.com/league/missrl/',
#  'https://stats.cfldb.com/league/mrfu/',
#  'https://stats.cfldb.com/league/mrl/',
#  'https://stats.cfldb.com/league/nwl/',
#  'https://stats.cfldb.com/league/oasfl/',
#  'https://stats.cfldb.com/league/orfu/',
#  'https://stats.cfldb.com/league/qrfu/',
#  'https://stats.cfldb.com/league/srfu/',
#  'https://stats.cfldb.com/league/ocsrfu/',
#  'https://stats.cfldb.com/league/wcrfl/',
#  'https://stats.cfldb.com/league/crfu/',
#  'https://stats.cfldb.com/league/cru/',
#  'https://stats.cfldb.com/league/nrfu/',
#  'https://stats.cfldb.com/league/wcrfu/',
#  'https://stats.cfldb.com/league/icrfu/',
#  'https://stats.cfldb.com/league/wicrfu/']

# %%
df=pd.concat([pd.DataFrame(records)])
df.to_csv("cfl.csv")

# %%
df.to_csv("cflgamess.csv")

# %%
for key in ct:
    print(key,":",eloLeague.ratingDict[key])

# %%
fn=str(row.season)+key+".txt"
            import os
            if(os.path.exists(fn))==True:
                contents = open(fn).read()
                if 'nan' not in contents:
                    contents=float(contents)
                    if(row.season==2021):
                        vegw=(14-contents)*-20
                        vegw=round(vegw)
                    if(row.season==2022):
                        vegw=(18-contents)*-20
                        vegw=round(vegw)
                    eloLeague.ratingDict[key]+=vegw

# %%
y=str('5t')
y.isdigit()

# %%
df=pd.DataFrame(records)
df.sort_values(by='Date',inplace=True)
df.season.unique()
df[df.index==1]

# %%
'15' in str(row.Result)

# %%
str(row.Result)

# %%
row.Index

# %%
import pandas as pd
df=pd.read_csv("https://ontheroadtovote.com/allcfl.csv")
df=df[df.index!=25592]
df['Notes']='none'
df.at[24366,'Notes']="McG forfited"
df= df.drop_duplicates()
df=df[df.season!=2020]
done=0
z=[]
g=1
yrs=[]
ty=0
tf=0
df=df[df.Result!='QUE 0 @ TOR']
df=df[df.Result!='CGY50  @ EDM']
df=df[df.Result!='STJC  vs W90CR  (ND)']
df=df[df.Result!='WRFC  vs W90CR  (ND)']
df=df[df.Result!='W90CR  vs WRFC  (ND)']
for row in df.itertuples():
    h=str(row.Result)
    if float(row.season) not in yrs:
        yrs.append(float(row.season))
        print(row.season)
    h=str(row.Result)
    
    if any(chr.isdigit() for chr in h)==False:
        tf+=1
        df=df[df.index!=row.Index]
    else:
        ty+=1
for row in df.itertuples():
    h=str(row.Result)
    if float(row.season) not in yrs:
    h=str(row.Result)
    
        
    res = []
    
    
    test_string=row.Result
    x=test_string.split()
    
    date=row.Date.split()
    datez=[]
    for i in date:
        
        if i.isnumeric()!=True:
            datez.append(str(i))
    
    if(done!=1):
        print(date)
        done=1
    dnum=date[2]
    date=datez
    
    if(date[1])=='Jan':
        month=1
    if(date[1])=='Feb':
        month=2
    if(date[1])=='Mar':
        month=3
    if(date[1])=='Apr':
        month=4
    if(date[1])=='May':
        month=5
    if(date[1])=='Jun':
        month=6
    if(date[1])=='Jul':
        month=7
    if(date[1])=='Aug':
        month=8
    if(date[1])=='Sep':
        month=9
    if(date[1])=='Oct':
        month=10
    if(date[1])=='Nov':
        month=11
    if(date[1])=='Dec':
        month=12
    fd=str(row.season)+str(month)+str(dnum)
    fd=fd.replace("Jan","1")
    fd=fd.replace("Feb","2")
    fd=fd.replace("Mar","3")
    fd=fd.replace("Apr","4")
    fd=fd.replace("May","5")
    fd=fd.replace("Jun","6")
    fd=fd.replace("Jul","7")
    fd=fd.replace("Aug","8")
    fd=fd.replace("Sep","9")
    fd=fd.replace("Oct","10")
    fd=fd.replace("Nov","11")
    fd=fd.replace("Dec","12")
    fd=fd.replace("'","")
    fd=float(fd)
    if g==1:
        g=0
    t1s=x[4]
    t2s=x[1]
    t1=x[3]
    t2=x[0]
    if(len(date)==4):
        time=str(date[2])+str(date[3])
    if(len(date)==5):
        time=str(date[3])+str(date[4])
    if "vs" in row.Result:
        t1s=x[1]
        t2s=x[4]
        t1=x[0]
        t2=x[3]
    df.at[row.Index,'score2']=t2s
    df.at[row.Index,'score1']=t1s
    df.at[row.Index,'team2']=t2
    df.at[row.Index,'team1']=t1
    df.at[row.Index,'fd']=fd
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()
# Out:
# 1944
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2021
# 2022
# 1907
# 1908
# 1909
# 1910
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1937
# 1942
# 1943
# 1928
# 1911
# 1912
# 1913
# 1914
# 1915
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1941
# 1927
# 1938
# 1939
# 1940
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1916
# done
# ['Wed', 'Sep', '27']
# Sep

# %%
row
# Out:
# Pandas(Index=36177, _1=36177, neutral=True, Date='Sat Apr 16', Result='WRFC  vs W90CR  (ND)', Attendance=nan, season=1891, Notes='none')

# %%
df=df[df.index!=25592]

# %%
df.sort_values(by='fd',inplace=True)
df
# Out:
#        Unnamed: 0  isneutral                 Date              Result  \
# 36199       36199       True            Mon May 9  W90CR 15 vs WRFC 3
# 36172       36172       True            Mon May 9  W90CR 15 vs WRFC 3
# 36181       36181       True            Mon May 9  W90CR 15 vs WRFC 3
# 36190       36190       True            Mon May 9  W90CR 15 vs WRFC 3
# 39453       39453       True            Sat May 6    OSBN 2 vs WRFC 6
# ...           ...        ...                  ...                 ...
# 23884       23884      False  Sun Nov 13\n1:00 PM     MTL 27 @ TOR 34
# 24171       24171       True  Sun Nov 20\n6:30 PM    TOR 24 vs WPG 23
# 23981       23981       True  Sun Nov 20\n6:30 PM    TOR 24 vs WPG 23
# 23886       23886       True  Sun Nov 20\n6:30 PM    TOR 24 vs WPG 23
# 24076       24076       True  Sun Nov 20\n6:30 PM    TOR 24 vs WPG 23
#
#       Attendance  season Notes  score2  score1 team2  team1          fd  \
# 36199        NaN    1891  none     3.0    15.0  WRFC  W90CR    189159.0
# 36172        NaN    1891  none     3.0    15.0  WRFC  W90CR    189159.0
# 36181        NaN    1891  none     3.0    15.0  WRFC  W90CR    189159.0
# 36190        NaN    1891  none     3.0    15.0  WRFC  W90CR    189159.0
# 39453        NaN    1892  none     6.0     2.0  WRFC   OSBN    189256.0
# ...          ...     ...   ...     ...     ...   ...    ...         ...
# 23884     21,331    2022  none    27.0    34.0   MTL    TOR  20221113.0
# 24171     33,330    2022  none    23.0    24.0   WPG    TOR  20221120.0
# 23981     33,330    2022  none    23.0    24.0   WPG    TOR  20221120.0
# 23886     33,330    2022  none    23.0    24.0   WPG    TOR  20221120.0
# 24076     33,330    2022  none    23.0    24.0   WPG    TOR  20221120.0
#
#        sseason
# 36199     1891
# 36172     1891
# 36181     1891
# 36190     1891
# 39453     1892
# ...        ...
# 23884     2022
# 24171     2022
# 23981     2022
# 23886     2022
# 24076     2022
#
# [40647 rows x 13 columns]

# %%
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()

# %%
df.to_csv("cflgamez.csv")

# %%
df[df.index==25592]
# Out:
# Empty DataFrame
# Columns: [isneutral, Date, Result, Attendance, season, Notes, score2, score1, team2, team1, fd, sseason]
# Index: []

# %%
### import pandas as pd
from bs4 import BeautifulSoup
arr=[]
import requests
records = []
html=requests.get("https://stats.cfldb.ca/league/")
soup=BeautifulSoup(html.text)
con=soup.find("div",{"class":"card-body"})
links=[]

for a in con.find_all("a"):
    a=str(a)
    a=a.split("href=")
    a=a[1]
    a=a.split(">")[0]
    a=a.replace('"',"")
    a=a.replace("'","")
    a="https://stats.cfldb.com"+str(a)
    links.append(a)
startyear=2023
endyear=2023
league='cfl'
for year in range(startyear,endyear+1):
    
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#IRFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#WIFU-reg"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#playoffs"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    regu="https://stats.cfldb.ca/league/"+league+"/schedule/"+str(year)+"/#greycup"
    import requests
    regh=requests.get(regu)
    regh=str(regh.text)
    reghh=regh.encode("ascii",errors='replace')
    reghz=reghh.decode("ascii",errors='replace')
    regz=BeautifulSoup(reghz)
    regt=regz.find_all("table")
    
    column_headers = ['Date','Result', 'Attendance', 'TV','season','neutral']
    for i in range(0,len(regt)):
        regtz=regt[i]
        
        for idy, rowz in enumerate(regtz.find_all('tr')):
            if idy == 0:
                continue
            cols = rowz.find_all('td')
            record = {}
            rowz=str(rowz)
            if "vs" in rowz:
                neutral=True
            else:
                neutral=False
            record[column_headers[5]]=neutral
            for idx, col in enumerate(cols):
                record[column_headers[idx]] = col.text.strip()
            record[column_headers[4]]=year
            
            records.append(record)
        i+=1
    
    
    print(year)
dff=pd.DataFrame(records)
arr=[]
df=pd.read_csv("https://ontheroadtovote.com/allcfl.csv")
for row in df.itertuples():
    arr.append([row.Date,row.Result,row.season,row.neutral])
print(len(arr))
for row in dff.itertuples():
    arr.append([row.Date,row.Result,row.season,row.neutral])
print(len(arr))
df=pd.concat([pd.DataFrame(arr,columns=['Date','Result','season','neutral'])])
import pandas as pd
df['Notes']='none'
df.at[24366,'Notes']="McG forfited"
df= df.drop_duplicates()
df=df[df.season!=2020]
done=0
z=[]
g=1
yrs=[]
ty=0
tf=0
df=df[df.Result!='QUE 0 @ TOR']
df=df[df.Result!='CGY50  @ EDM']
df=df[df.Result!='STJC  vs W90CR  (ND)']
df=df[df.Result!='WRFC  vs W90CR  (ND)']
df=df[df.Result!='W90CR  vs WRFC  (ND)']
for row in df.itertuples():
    h=str(row.Result)
    if float(row.season) not in yrs:
        yrs.append(float(row.season))
    h=str(row.Result)
    
    if any(chr.isdigit() for chr in h)==False:
        tf+=1
        df=df[df.index!=row.Index]
    else:
        ty+=1
for row in df.itertuples():
    h=str(row.Result)
    if float(row.season) not in yrs:
        h=str(row.Result)
    
        
    res = []
    
    
    test_string=row.Result
    x=test_string.split()
    
    date=row.Date.split()
    datez=[]
    for i in date:
        
        if i.isnumeric()!=True:
            datez.append(str(i))
    
    if(done!=1):
        print(date)
        done=1
    dnum=date[2]
    if len(dnum)==1:
        dnum=str("0")+str(dnum)
    date=datez
    
    if(date[1])=='Jan':
        month=str("01")
    if(date[1])=='Feb':
        month="02"
    if(date[1])=='Mar':
        month="03"
    if(date[1])=='Apr':
        month="04"
    if(date[1])=='May':
        month="05"
    if(date[1])=='Jun':
        month="06"
    if(date[1])=='Jul':
        month="07"
    if(date[1])=='Aug':
        month="08"
    if(date[1])=='Sep':
        month="09"
    if(date[1])=='Oct':
        month=10
    if(date[1])=='Nov':
        month=11
    if(date[1])=='Dec':
        month=12
    fd=str(row.season)+str(month)+str(dnum)
    fd=fd.replace("Jan","1")
    fd=fd.replace("Feb","2")
    fd=fd.replace("Mar","3")
    fd=fd.replace("Apr","4")
    fd=fd.replace("May","5")
    fd=fd.replace("Jun","6")
    fd=fd.replace("Jul","7")
    fd=fd.replace("Aug","8")
    fd=fd.replace("Sep","9")
    fd=fd.replace("Oct","10")
    fd=fd.replace("Nov","11")
    fd=fd.replace("Dec","12")
    fd=fd.replace("'","")
    fd=float(fd)
    if g==1:
        g=0
    t1s=x[4]
    t2s=x[1]
    t1=x[3]
    t2=x[0]
    if(len(date)==4):
        time=str(date[2])+str(date[3])
    if(len(date)==5):
        time=str(date[3])+str(date[4])
    if "vs" in row.Result:
        t1s=x[1]
        t2s=x[4]
        t1=x[0]
        t2=x[3]
    df.at[row.Index,'score2']=t2s
    df.at[row.Index,'score1']=t1s
    df.at[row.Index,'team2']=t2
    df.at[row.Index,'team1']=t1
    df.at[row.Index,'fd']=fd
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()
vegdf=pd.read_csv("https://ontheroadtovote.com/ncaab/cflw.csv")
for row in vegdf.iterrows():
    fn='2022'+row[1]['Team']+".txt"
    file=open(fn,"w")
    file.write(str(row[1]['2022']))
    file.close()
    fn='2021'+row[1]['Team']+".txt"
    if(row[1]['2021'])!='nan':
        file=open(fn,"w")
        file.write(str(row[1]['2021']))
        file.close()
u={}
u['yes']=0
h=[]
class Elo:
    
    
    def __init__(self,k,g=1,homefield = 100):
        self.ratingDict = {}
        self.k = k
        self.homefield= homefield

    def addPlayer(self,name,rating = 1500):
        self.ratingDict[name] = rating
    def gameOver(self, winner, loser, ws,ls,neutral,winnerHome):
        if 'True' in str(neutral):
            hfaz=0
        else:
            hfaz=hfa
        if winnerHome:
            result = self.expectResult(self.ratingDict[winner] + hfaz, self.ratingDict[loser])
        else:
            result = self.expectResult(self.ratingDict[winner], self.ratingDict[loser]+hfaz)
        pd=abs(ws-ls)
        tie=0
        if(ws==ls):
            tie=1
       
        if winnerHome==True:
            elo_diff=((eloLeague.ratingDict[winner]+hfaz)-eloLeague.ratingDict[loser])
        if winnerHome==False:
            elo_diff=((eloLeague.ratingDict[winner])-(eloLeague.ratingDict[loser]+hfaz))
        elo_diff=abs(elo_diff)
        if elo_diff==0:
            elo_diff=0.00001
        if ws!=ls:
            
            mult=math.log(pd+1)*(2.2/elo_diff*0.0001+2.2)
        if ws==ls:
            
            mult=math.log(pd+1)*(2.2/1*0.0001+2.2)  
        shift=(self.k*mult)*(1 - result)  
        if u['yes']==0:
            print((self.k*mult)*(1 - result)  )
        self.ratingDict[winner]+=shift
        self.ratingDict[loser]-=shift
    def expectResult(self, p1, p2):
        exp = (p2-p1)/400.0
        if u['yes']==0:
            print(1/((10.0**(exp))+1))
            u['yes']=1
        return 1/((10.0**(exp))+1)

from sklearn.metrics import mean_squared_error
df=df.rename(columns={'neutral':'isneutral'})
df=df.astype({"team1":"string","team2":"string","score2":float,'score1':float,'fd':float})
df["score1"] = pd.to_numeric(df["score1"])
df["score2"] = pd.to_numeric(df["score2"])
df["sseason"] = pd.to_numeric(df["season"])
df=df.drop_duplicates()
df.sort_values(by='season',inplace=True)
df.sort_values(by='fd',inplace=True)
nn=df[df.isneutral==False]
for row in nn.itertuples():
    h.append(row.score1-row.score2)
hfa=round(np.mean(h))*20
eloLeague=Elo(k=20,homefield=hfa)
teams=set(df.team1.tolist()+df.team2.tolist())
for team in teams:
    eloLeague.addPlayer(team,rating=1500)
w=0
l=0

msqe={}
for i in range(10,50):
    msqe[i]=[]
cs=1883
for row in df.itertuples():
    if(row.season>cs):
        csdf=df[df.season==row.season]
        ct=set(csdf.team1.tolist()+csdf.team2.tolist())
        lsdf=df[df.season<row.season]
        lt=set(lsdf.team1.tolist()+lsdf.team2.tolist())
        for key in eloLeague.ratingDict.keys():
            fn=str(row.season)+key+".txt"
            import os
            if(os.path.exists(fn))==True:
                contents = open(fn).read()
                if 'nan' not in contents:
                    contents=float(contents)
                    if(row.season==2021):
                        vegw=(7-contents)*-20
                        vegw=round(vegw)
                    if(row.season==2022):
                        vegw=(9-contents)*-20
                        vegw=round(vegw)
                    vegw=vegw*(2/3)
                    eloLeague.ratingDict[key]+=vegw
            if(key in lt and key in ct):
                eloLeague.ratingDict[key]=((2/3)*eloLeague.ratingDict[key])+(1500*(1/3))
        cs=float(row.season)
    if 'True' in str(row.isneutral):
        hfaz=0
    else:
        hfaz=hfa
    ediff=(eloLeague.ratingDict[row.team1]+hfaz)-eloLeague.ratingDict[row.team2]
    for i in range(10,50):
        spread=ediff/i
        spread=round(spread)
        if spread==0:
            spread=1
        msqe[i].append(mean_squared_error([row.score1-row.score2], [spread]))
    if(row.score1>row.score2):
        wh=True
        
        if(row.isneutral==True):
            hfa=0
        if((eloLeague.ratingDict[row.team1]+hfaz)>eloLeague.ratingDict[row.team2]):
            w+=1
        if((eloLeague.ratingDict[row.team1]+hfaz)<eloLeague.ratingDict[row.team2]):
            l+=1
        eloLeague.gameOver(row.team1,row.team2,row.score1,row.score2,row.isneutral,wh)
    if(row.score1<row.score2):
        
        wh=False
        
        if(row.isneutral==True):
            hfaz=0
        if((eloLeague.ratingDict[row.team1]+hfaz)>eloLeague.ratingDict[row.team2]):
            l+=1
        if((eloLeague.ratingDict[row.team1]+hfaz)<eloLeague.ratingDict[row.team2]):
            w+=1
        eloLeague.gameOver(row.team2,row.team1,row.score2,row.score1,row.isneutral,wh)
    if(row.score1==row.score2):
        wh=True
        eloLeague.gameOver(row.team1,row.team2,row.score1,row.score2,row.isneutral,wh)
        
        
msqez={}
for key in msqe.keys():
    msqez[key]=np.mean(msqe[key])
mas=min(msqez.items(), key=operator.itemgetter(1))[0:]
mas=str(mas)
mas=mas.split("(")[1]
mas=mas.split(",")[0]
team1=input("team1")
team2=input("team2")
neutral=input('neutral')
hfa=60
if 'True' in str(neutral):
    hfa=0
t1e=eloLeague.ratingDict[team1]+hfa
t2e=eloLeague.ratingDict[team2]
spread=t1e-t2e
spread=spread/float(mas)
spread=round(spread)
if spread==0:
    spread=1
print(team1+" will beat "+team2+" by "+str(spread))
# Out:
# 2023
# 41620
# 42000
# ['Wed', 'Sep', '27']
# 0.5

# %%
h=[]
nn=df[df.isneutral==False]
for row in nn.itertuples():
    h.append(row.score1-row.score2)
np.mean(h)
# Out:
# 3.2106149012567324

# %%
team1=input("team1")
team2=input("team2")
neutral=input('neutral')
hfa=60
if 'True' in str(neutral):
    hfa=0
t1e=eloLeague.ratingDict[team1]+hfa
t2e=eloLeague.ratingDict[team2]
spread=t1e-t2e

# %%
sorted(msqez, key=msqe.get,reverse=False)[:1]
# Out:
# [46]

# %%
min(msqez.items(), key=operator.itemgetter(1))[0:]
# Out:
# (33, 224.9360303932642)

# %%
msqez=dict(msqez)
msqez
# Out:
# {10: 463.6089947633227,
#  11: 405.17999794640104,
#  12: 362.85717219427045,
#  13: 331.38987575726463,
#  14: 307.6672142930486,
#  15: 289.7089023513708,
#  16: 275.559092309272,
#  17: 264.6626963753979,
#  18: 255.94783858712393,
#  19: 249.22569052264092,
#  20: 243.67953588664133,
#  21: 239.47674299209365,
#  22: 236.03408974227332,
#  23: 233.25392750795768,
#  24: 231.26501694219118,
#  25: 229.44994352602936,
#  26: 228.28863332991068,
#  27: 227.03121470376834,
#  28: 226.37488448506008,
#  29: 225.8609713522949,
#  30: 225.38710339870624,
#  31: 225.22127528493687,
#  32: 225.17548002875037,
#  33: 224.9360303932642,
#  34: 225.03337098264709,
#  35: 225.29992812403736,
#  36: 225.30680768046,
#  37: 225.50046205975974,
#  38: 225.94619570797823,
#  39: 226.29705308553238,
#  40: 226.68025464626757,
#  41: 227.01683951124346,
#  42: 227.35886641338948,
#  43: 227.75962624499437,
#  44: 228.07762603963445,
#  45: 228.41338946503748,
#  46: 228.84762295923605,
#  47: 229.24992299004003,
#  48: 229.62285655611458,
#  49: 229.95030290584248}

# %%
msqez={}
for key in msqe.keys():
    msqez[key]=np.mean(msqe[key])
min(msqez.items(), key=operator.itemgetter(1))[0:]
